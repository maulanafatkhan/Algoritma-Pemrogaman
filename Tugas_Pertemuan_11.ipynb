# %%
import datetime
import os
import random
import string

buku_template = {
    'judul': 'Judul Buku',
    'penulis': 'Nama Penulis',
    'tahun_terbit': 0,
    'tanggal_terakhir_pinjaman': datetime.datetime(1111, 1, 1),
    'status': 'TERSEDIA'
}

data_buku = {}

while True:
    os.system("cls")
    print(f"{'SISTEM PERPUSTAKAAN':^50}")
    print(f"{'DATA BUKU':^50}")
    print("-" * 50)

    buku = dict.fromkeys(buku_template.keys())

    buku['judul'] = input("Judul Buku\t\t: ")
    buku['penulis'] = input("Penulis Buku\t\t: ")
    buku['tahun_terbit'] = int(input("Tahun Terbit\t\t: "))

    print("\nMasukkan tanggal terakhir pinjam:")
    tahun = int(input("Tahun (YYYY)\t\t: "))
    bulan = int(input("Bulan (1-12)\t\t: "))
    tanggal = int(input("Tanggal (1-31)\t\t: "))
    buku['tanggal_terakhir_pinjaman'] = datetime.datetime(tahun, bulan, tanggal)

    buku['status'] = input("Status (TERSEDIA/TIDAK)\t: ").upper()

    KEY = ''.join((random.choice(string.ascii_uppercase) for i in range(6)))
    data_buku.update({KEY: buku})

    print("\nData Buku Saat Ini:")
    print(f"{'KEY':<8} {'JUDUL':<25} {'PENULIS':<20} {'TAHUN':<8} {'TERAKHIR PINJAM':<15} {'STATUS':<10}")
    print("-" * 90)

    for key in data_buku:
        JUDUL = data_buku[key]['judul']
        PENULIS = data_buku[key]['penulis']
        TAHUN = data_buku[key]['tahun_terbit']
        PINJAM = data_buku[key]['tanggal_terakhir_pinjaman'].strftime("%x")
        STATUS = data_buku[key]['status']
        print(f"{key:<8} {JUDUL:<25} {PENULIS:<20} {TAHUN:<8} {PINJAM:<15} {STATUS:<10}")

    print("\n")
    is_done = input("Tambah buku lagi? (y/n): ").lower()
    if is_done == "n":
        break

print("\nProgram selesai. Terima kasih telah menggunakan sistem perpustakaan.")
# Out:
#                SISTEM PERPUSTAKAAN
#                     DATA BUKU
# --------------------------------------------------
# Judul Buku		: Laut Bercerita
# Penulis Buku		: Leila S. Chudori
# Tahun Terbit		: 2017
#
# Masukkan tanggal terakhir pinjam:
# Tahun (YYYY)		: 2025
# Bulan (1-12)		: 11
# Tanggal (1-31)		: 10
# Status (TERSEDIA/TIDAK)	: tersedia
#
# Data Buku Saat Ini:
# KEY      JUDUL                     PENULIS              TAHUN    TERAKHIR PINJAM STATUS
# ------------------------------------------------------------------------------------------
# QSTVEG   Laut Bercerita            Leila S. Chudori     2017     11/10/25        TERSEDIA
#
#
# Tambah buku lagi? (y/n): n
#
# Program selesai. Terima kasih telah menggunakan sistem perpustakaan.
